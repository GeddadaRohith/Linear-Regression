# %%
import pandas as pd 
x={
    "alpha":["car","bike","areo","van"],
    "numbers":[1,2,3,4],
    "code":["1a","2b","3c","4b"]
}
myvar=pd.DataFrame(x)
print(myvar)
# Out:
#   alpha  numbers code
# 0   car        1   1a
# 1  bike        2   2b
# 2  areo        3   3c
# 3   van        4   4b

# %%
 print(myvar.loc[[0,3]])
# Out:
#   alpha  numbers code
# 0   car        1   1a
# 3   van        4   4b

# %%
import pandas as pd
x=[9,8,7,6,5,4,3,2,1,0]
myvar=pd.Series(x,index=["9*1","9*2","9*3","9*4","9*5","9*6","9*7","9*8","9*9","9*10"])
print(myvar)
# Out:
# 9*1     9
# 9*2     8
# 9*3     7
# 9*4     6
# 9*5     5
# 9*6     4
# 9*7     3
# 9*8     2
# 9*9     1
# 9*10    0
# dtype: int64

# %%
import pandas as pd 
a={"jan":1,"feb":2,"mar":3}
myvar=pd.Series(a,index=["jan","feb"])
print(myvar)
print(myvar["jan"])
# Out:
# jan    1
# feb    2
# dtype: int64
# 1

# %%
import pandas as pd
x=pd.read_csv('student.csv')
print(x.to_string())
# Out:
#      Student_id  Age  Gender      Grade Employed
# 0             1   19    Male  1st Class      yes
# 1             2   20  Female  2nd Class       no
# 2             3   18    Male  1st Class       no
# 3             4   21  Female  2nd Class       no
# 4             5   19    Male  1st Class       no
# 5             6   20    Male  2nd Class      yes
# 6             7   19  Female  3rd Class      yes
# 7             8   21    Male  3rd Class      yes
# 8             9   22  Female  3rd Class      yes
# 9            10   21    Male  1st Class       no
# 10           11   20  Female  3rd Class      yes
# 11           12   20    Male  1st Class       no
# 12           13   19    Male  1st Class      yes
# 13           14   20  Female  3rd Class       no
# 14           15   19    Male  1st Class      yes
# 15           16   19  Female  2nd Class       no
# 16           17   20    Male  2nd Class      yes
# 17           18   18  Female  3rd Class       no
# ...

# %%
print(x.loc[[7,54,122,9]])
# Out:
#      Student_id  Age  Gender      Grade Employed
# 7             8   21    Male  3rd Class      yes
# 54           55   20    Male  2nd Class       no
# 122         123   19  Female  3rd Class      yes
# 9            10   21    Male  1st Class       no

# %%
print(x.head(9))
# Out:
#    Student_id  Age  Gender      Grade Employed
# 0           1   19    Male  1st Class      yes
# 1           2   20  Female  2nd Class       no
# 2           3   18    Male  1st Class       no
# 3           4   21  Female  2nd Class       no
# 4           5   19    Male  1st Class       no
# 5           6   20    Male  2nd Class      yes
# 6           7   19  Female  3rd Class      yes
# 7           8   21    Male  3rd Class      yes
# 8           9   22  Female  3rd Class      yes

# %%
print(x.tail(6))
# Out:
#      Student_id  Age  Gender      Grade Employed
# 226         227   22    Male  3rd Class       no
# 227         228   21  Female  1st Class       no
# 228         229   20    Male  2nd Class       no
# 229         230   20    Male  3rd Class      yes
# 230         231   19  Female  1st Class      yes
# 231         232   20    Male  3rd Class      yes

# %%
print(x.info)
# Out:
# <bound method DataFrame.info of      Student_id  Age  Gender      Grade Employed
# 0             1   19    Male  1st Class      yes
# 1             2   20  Female  2nd Class       no
# 2             3   18    Male  1st Class       no
# 3             4   21  Female  2nd Class       no
# 4             5   19    Male  1st Class       no
# ..          ...  ...     ...        ...      ...
# 227         228   21  Female  1st Class       no
# 228         229   20    Male  2nd Class       no
# 229         230   20    Male  3rd Class      yes
# 230         231   19  Female  1st Class      yes
# 231         232   20    Male  3rd Class      yes
#
# [232 rows x 5 columns]>

# %% [markdown]
# # cleaning empty data

# %%
import pandas as pd 
df=pd.read_csv('Wholesale customers data.csv')
print(df.to_string())
# Out:
#      Channel  Region   Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0          2       3   12669   9656     7561     214              2674        1338
# 1          2       3    7057   9810     9568    1762              3293        1776
# 2          2       3    6353   8808     7684    2405              3516        7844
# 3          1       3   13265   1196     4221    6404               507        1788
# 4          2       3   22615   5410     7198    3915              1777        5185
# 5          2       3    9413   8259     5126     666              1795        1451
# 6          2       3   12126   3199     6975     480              3140         545
# 7          2       3    7579   4956     9426    1669              3321        2566
# 8          1       3    5963   3648     6192     425              1716         750
# 9          2       3    6006  11093    18881    1159              7425        2098
# ...

# %%
import pandas as pd
df=pd.read_csv('Wholesale customers data.csv')
x=df.dropna()
print(x.to_string())
# Out:
#      Channel  Region   Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0          2       3   12669   9656     7561     214              2674        1338
# 1          2       3    7057   9810     9568    1762              3293        1776
# 2          2       3    6353   8808     7684    2405              3516        7844
# 3          1       3   13265   1196     4221    6404               507        1788
# 4          2       3   22615   5410     7198    3915              1777        5185
# 5          2       3    9413   8259     5126     666              1795        1451
# 6          2       3   12126   3199     6975     480              3140         545
# 7          2       3    7579   4956     9426    1669              3321        2566
# 8          1       3    5963   3648     6192     425              1716         750
# 9          2       3    6006  11093    18881    1159              7425        2098
# ...

# %%
import pandas as pd 
df=pd.read_csv('Wholesale customers data.csv')
x=df.dropna(inplace=True)
print(x)
# Out:
# None

# %% [markdown]
# # Replacing

# %%
import pandas as pd 
df=pd.read_csv('titanic.csv')
df.fillna(2222,inplace=True)
print(df.to_string())
# Out:
#      survived  pclass     sex      age  sibsp  parch      fare embarked   class    who  adult_male  deck  embark_town alive  alone
# 0           0       3    male    22.00      1      0    7.2500        S   Third    man        True  2222  Southampton    no  False
# 1           1       1  female    38.00      1      0   71.2833        C   First  woman       False     C    Cherbourg   yes  False
# 2           1       3  female    26.00      0      0    7.9250        S   Third  woman       False  2222  Southampton   yes   True
# 3           1       1  female    35.00      1      0   53.1000        S   First  woman       False     C  Southampton   yes  False
# 4           0       3    male    35.00      0      0    8.0500        S   Third    man        True  2222  Southampton    no   True
# 5           0       3    male  2222.00      0      0    8.4583        Q   Third    man        True  2222   Queenstown    no   True
# ...

# %%
import pandas as pd
df=pd.read_csv('titanic.csv')
df["age"].fillna(7777,inplace=True)
print(df.to_string())
# Out:
#      survived  pclass     sex      age  sibsp  parch      fare embarked   class    who  adult_male deck  embark_town alive  alone
# 0           0       3    male    22.00      1      0    7.2500        S   Third    man        True  NaN  Southampton    no  False
# 1           1       1  female    38.00      1      0   71.2833        C   First  woman       False    C    Cherbourg   yes  False
# 2           1       3  female    26.00      0      0    7.9250        S   Third  woman       False  NaN  Southampton   yes   True
# 3           1       1  female    35.00      1      0   53.1000        S   First  woman       False    C  Southampton   yes  False
# 4           0       3    male    35.00      0      0    8.0500        S   Third    man        True  NaN  Southampton    no   True
# 5           0       3    male  7777.00      0      0    8.4583        Q   Third    man        True  NaN   Queenstown    no   True
# ...

# %%
import pandas as pd 
df=pd.read_csv('titanic.csv')
x=df["age"].mode()[0]
df["age"].fillna(x,inplace=True)
print(x)
print(df.to_string())
# Out:
# 24.0
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class    who  adult_male deck  embark_town alive  alone
# 0           0       3    male  22.00      1      0    7.2500        S   Third    man        True  NaN  Southampton    no  False
# 1           1       1  female  38.00      1      0   71.2833        C   First  woman       False    C    Cherbourg   yes  False
# 2           1       3  female  26.00      0      0    7.9250        S   Third  woman       False  NaN  Southampton   yes   True
# 3           1       1  female  35.00      1      0   53.1000        S   First  woman       False    C  Southampton   yes  False
# 4           0       3    male  35.00      0      0    8.0500        S   Third    man        True  NaN  Southampton    no   True
# 5           0       3    male  24.00      0      0    8.4583        Q   Third    man        True  NaN   Queenstown    no   True
# ...

# %%
import pandas as pd 

df=pd.read_csv('mark.csv')
print(df.to_string())
# Out:
#      Student_id  Mark     City
# 0             1    95  Chennai
# 1             2    70    Delhi
# 2             3    98   Mumbai
# 3             4    75     Pune
# 4             5    89    Kochi
# 5             6    69  Gwalior
# 6             7    52   Bhopal
# 7             8    54  Chennai
# 8             9    55    Delhi
# 9            10    94   Mumbai
# 10           11    52     Pune
# 11           12    90    Kochi
# 12           13    92  Gwalior
# 13           14    55   Bhopal
# 14           15    97     Pune
# 15           16    77    Kochi
# 16           17    68  Gwalior
# 17           18    51   Bhopal
# 18           19    72  Chennai
# 19           20    79    Delhi
# 20           21    49   Mumbai
# 21           22    78     Pune
# 22           23    76  Chennai
# 23           24    43    Delhi
# 24           25    89   Mumbai
# 25           26    75     Pune
# 26           27    45    Kochi
# 27           28    98  Gwalior
# 28           29    54   Bhopal
# ...

# %%
print(df.loc[2])
# Out:
# Student_id         3
# Mark              98
# City          Mumbai
# Name: 2, dtype: object

# %%
df.loc[2,'Mark']=52
print(df.loc[2])
# Out:
# Student_id         3
# Mark              52
# City          Mumbai
# mark             5.0
# Name: 2, dtype: object

# %%
for x in df.index:
    if df.loc[x,"Mark"]>70:
        df.loc[x,"Mark"]=0
print(df.to_string())
# Out:
#      Student_id  Mark     City  mark
# 0             1     0  Chennai   NaN
# 1             2    70    Delhi   NaN
# 2             3    52   Mumbai   5.0
# 3             4     0     Pune   NaN
# 4             5     0    Kochi   NaN
# 5             6    69  Gwalior   NaN
# 6             7    52   Bhopal   NaN
# 7             8    54  Chennai   NaN
# 8             9    55    Delhi   NaN
# 9            10     0   Mumbai   NaN
# 10           11    52     Pune   NaN
# 11           12     0    Kochi   NaN
# 12           13     0  Gwalior   NaN
# 13           14    55   Bhopal   NaN
# 14           15     0     Pune   NaN
# 15           16     0    Kochi   NaN
# 16           17    68  Gwalior   NaN
# 17           18    51   Bhopal   NaN
# 18           19     0  Chennai   NaN
# 19           20     0    Delhi   NaN
# 20           21    49   Mumbai   NaN
# 21           22     0     Pune   NaN
# 22           23     0  Chennai   NaN
# 23           24    43    Delhi   NaN
# ...

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 227    False
# 228    False
# 229    False
# 230    False
# 231    False
# Length: 232, dtype: bool

# %%
df.drop_dupilicated
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.drop_dupilicated
#
# NameError: name 'df' is not defined

# %%
import pandas as pd 
df=pd.read_csv('titanic.csv')
print(df.to_string())
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class    who  adult_male deck  embark_town alive  alone
# 0           0       3    male  22.00      1      0    7.2500        S   Third    man        True  NaN  Southampton    no  False
# 1           1       1  female  38.00      1      0   71.2833        C   First  woman       False    C    Cherbourg   yes  False
# 2           1       3  female  26.00      0      0    7.9250        S   Third  woman       False  NaN  Southampton   yes   True
# 3           1       1  female  35.00      1      0   53.1000        S   First  woman       False    C  Southampton   yes  False
# 4           0       3    male  35.00      0      0    8.0500        S   Third    man        True  NaN  Southampton    no   True
# 5           0       3    male    NaN      0      0    8.4583        Q   Third    man        True  NaN   Queenstown    no   True
# ...

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import pandas as pd
df=pd.read_csv('titanic.csv')
new_df=df.dropna()
new_df.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
import pandas as pd 
df=pd.read_csv('titanic.csv')
df.fillna(15,inplace=True)
df.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
print(df.to_string())
# Out:
#      survived  pclass     sex        age  sibsp  parch      fare embarked   class    who  adult_male    deck  embark_town alive  alone
# 0           0       3    male      22.00      1      0    7.2500        S   Third    man        True  122225  Southampton    no  False
# 1           1       1  female      38.00      1      0   71.2833        C   First  woman       False       C    Cherbourg   yes  False
# 2           1       3  female      26.00      0      0    7.9250        S   Third  woman       False  122225  Southampton   yes   True
# 3           1       1  female      35.00      1      0   53.1000        S   First  woman       False       C  Southampton   yes  False
# 4           0       3    male      35.00      0      0    8.0500        S   Third    man        True  122225  Southampton    no   True
# 5           0       3    male  122225.00      0      0    8.4583        Q   Third    man        True  122225   Queenstown    no   True
# ...

# %%
import pandas as pd
df=pd.read_csv('titanic.csv')
for x in df.index:
    if df.loc[x,"fare"]>25:
        df.loc[x,"fare"]=25
print(df.to_string())
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare embarked   class    who  adult_male deck  embark_town alive  alone
# 0           0       3    male  22.00      1      0   7.2500        S   Third    man        True  NaN  Southampton    no  False
# 1           1       1  female  38.00      1      0  25.0000        C   First  woman       False    C    Cherbourg   yes  False
# 2           1       3  female  26.00      0      0   7.9250        S   Third  woman       False  NaN  Southampton   yes   True
# 3           1       1  female  35.00      1      0  25.0000        S   First  woman       False    C  Southampton   yes  False
# 4           0       3    male  35.00      0      0   8.0500        S   Third    man        True  NaN  Southampton    no   True
# 5           0       3    male    NaN      0      0   8.4583        Q   Third    man        True  NaN   Queenstown    no   True
# ...
